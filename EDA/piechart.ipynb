# %%
import matplotlib.pyplot as plt

region = ['North', 'East', 'West', 'South']
revenue = [10000, 14000, 25000, 22000]
plt.pie(revenue, labels = region, colors = ['gold', 'red', 'aqua', 'green'], autopct = '%1.1f%%')
plt.title('Sales by Region')
plt.show()

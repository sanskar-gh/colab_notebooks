# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative = 1, noise = 20, random_state = 42, n_targets=1)

# %%
X
# Out:
# array([[ 0.64768854],
#        [-0.1382643 ],
#        [ 1.52302986],
#        [ 0.49671415]])

# %%
y
# Out:
# array([-1.51241417, 18.05312487, 13.25870861, 13.33049253])

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-2.79666617])

# %%
lr.intercept_
# Out:
# np.float64(12.550787777355765)

# %%
y_predict = lr.predict(X)

# %%
plt.scatter(X,y)
plt.plot(X, y_pred)

# %%
y_pred = ((78.35 * X) + 100).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='#00a65a',label='b = 0')
plt.legend()
plt.show()

# %%
b = -100
m = 78.35
lr = 0.01

epochs = 100

for i in range(epochs):
  loss_slope = -2 * np.sum(y - m*X.ravel() - b)
  b = b - (lr * loss_slope)

  y_pred = m * X + b

  plt.plot(X,y_pred)

plt.scatter(X,y)

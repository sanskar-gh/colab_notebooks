# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('sample_submission.csv')
df
# Out:
#        ImageId  Label
# 0            1      0
# 1            2      0
# 2            3      0
# 3            4      0
# 4            5      0
# ...        ...    ...
# 27995    27996      0
# 27996    27997      0
# 27997    27998      0
# 27998    27999      0
# 27999    28000      0
#
# [28000 rows x 2 columns]
